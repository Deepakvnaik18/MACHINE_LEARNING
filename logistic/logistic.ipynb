# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.DataFrame({"projected score":[300,250,99,85,180],"result":["win","win","lost","lost","win"]})

df
# Out:
#    projected score result
# 0              300    win
# 1              250    win
# 2               99   lost
# 3               85   lost
# 4              180    win

# %%
x = df[["projected score"]]

y = df["result"]

# %%
xtrain,xtest,ytrain,ytest  =  train_test_split(x,y,train_size=0.8,random_state=42)

xtrain
# Out:
#    projected score
# 4              180
# 2               99
# 0              300
# 3               85

# %%
model = LogisticRegression()

model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
s = pd.DataFrame({"projected score":[10,139,140,230,350]})

pred = model.predict(xtest)

pred
# Out:
# array(['win'], dtype=object)

# %%
model.score(xtest,ytest)
# Out:
# 1.0

# %%
plt.scatter(xtest,pred)
